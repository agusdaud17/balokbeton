# %%
import balokBeton.Balok as bk
import balokBeton.Sketch as sk

# %% [markdown]
# # Flanged

# %%
bf = bk.Flanged(name="B1")
bf.material(fc=21,fy=400)
bf.dimension(bw=250, h=450, hf=120, be=1800, ds=40)
bf.rebar(rebar = [["D16",3]], Dv="D10")
bf.run()

# %%
sk.Draw(bf).plot(size=(15,15),font=13)

# %%
bf.__dict__
# Out:
# {'fc': 21,
#  'fy': 400,
#  'Es': 200000,
#  'code': 'SNI 2847:2019',
#  'std': <module 'balokBeton.SNI2847' from 'C:\\Users\\Asus\\AppData\\Roaming\\Python\\Python310\\site-packages\\balokBeton\\SNI2847.py'>,
#  'unit': 'metric',
#  'list_bar': {'D6': [6, 28],
#   'D8': [8, 50],
#   'D10': [10, 79],
#   'D13': [13, 133],
#   'D16': [16, 201],
#   'D19': [19, 284],
#   'D22': [22, 380],
#   'D25': [25, 491],
#   'D29': [29, 661],
#   'D32': [32, 804]},
#  'mm': 1,
#  'to_kNm': 1e-06,
#  'name': 'B1',
#  'jenis_balok': 'Flanged',
#  'bw': 250,
#  'h': 450,
#  'hf': 120,
#  'be': 1800,
#  'ds': 40,
#  'decimal': 2,
#  'legs': 2,
#  'barloc': 'bottom',
#  'effective_height': 'by program',
#  'longBar': [['D16', 3]],
#  'row': 1,
#  'noDv': 'D10',
#  'Dv': 10,
#  'sv': 25,
#  's': 150,
#  'nslab': 0,
#  'noSlab': 'D13',
#  'Dslab': 13,
#  'Abar_slab': 133,
#  'As_slab': 0,
#  'AsRow': [603],
#  'NBar': [3],
#  'clearHSpace': [51.0],
#  'HSpacing': [67.0],
#  'dRow': [58.0],
# ...
